# %% [markdown]
# ## 기본 문법 두번째 시간

# %% [markdown]
# - 개념1
# - 개념2

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## 리스트 표현
#
# - 대괄호 [] 안에 값들을 쉼표(,) 로 구분하여 만듦

# %%
my_list_1 = []
my_list_2 = [1, "a", 3, "b", 5]
my_list_3 = [1, 2, 3, "Python", ["hello", "world", "!!!"]]

print(my_list_2[4])
print(my_list_3[4][-1][1])
# Out:
# 5
# !
